# %% [markdown]
# # Input Style Recommender Engine

# %% [markdown]
# ## In this notebook we make an item based recommender system to input a STYLE which likes one user and get the TOP 5 SIMILAR BEERS

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
# %matplotlib inline
import sys
reload(sys)
sys.setdefaultencoding("utf-8")
import ipywidgets as widgets
from ipywidgets import interactive

# %%
df = pd.read_csv('df_to_recommender.csv')

# %%
df.shape
# Out:
# (7771, 27)

# %%
rated = df.num_rated_beers
stats = rated.describe()
stats
# Out:
# count    7771.000000
# mean      951.726161
# std       411.347573
# min       501.000000
# 25%       649.000000
# 50%       837.000000
# 75%      1161.000000
# max      2197.000000
# Name: num_rated_beers, dtype: float64

# %%
df=df[['user_id', 'profile_name', 'Id', 'names', 'num_rated_beers', 'style','overall']].copy()

# %%
df.tail()
# Out:
#       user_id profile_name     Id                              names  \
# 7766    13567      acrawf6  23236                    Zea Amber Lager
# 7767    13567      acrawf6  32318   Zea Category 5 American Pale Ale
# 7768    13567      acrawf6  32319                       German Lager
# 7769    13567      acrawf6  40482       Gordon Biersch Smoked M├ñrzen
# 7770    13567      acrawf6  30074                    Special Block 6
#
#       num_rated_beers                     style  overall
# 7766              522              Vienna Lager      4.0
# 7767              522   American Pale Ale (APA)      4.5
# 7768              522      M├ñrzen / Oktoberfest      4.5
# 7769              522      M├ñrzen / Oktoberfest      4.0
# 7770              522          Belgian Pale Ale      4.0

# %% [markdown]
# ### It is strange, but the following function does not work if our column it is called "style" because a kind of conflict with "Styler" command, therefore we change the column name to "estilo"

# %%
df.rename(columns={'style': 'estilo'}, inplace=True)

# %%
df.columns
# Out:
# Index([u'user_id', u'profile_name', u'Id', u'names', u'num_rated_beers',
#        u'estilo', u'overall'],
#       dtype='object')

# %%
## to check some profile names and input as sample_user = ' xxx'
ToKnowNames = df.groupby(['estilo'])['names'].count().sort_values(ascending = False).head(10)
ToKnowNames
# Out:
# estilo
#  American IPA                      523
#  American Pale Ale (APA)           452
#  American Amber / Red Ale          321
#  American Porter                   295
#  Hefeweizen                        209
#  American Double / Imperial IPA    200
#  German Pilsener                   171
#  Saison / Farmhouse Ale            170
#  American Stout                    158
#  M├ñrzen / Oktoberfest              147
# Name: names, dtype: int64

# %%
ratings = df.pivot_table(values='overall', index='estilo', columns='names')
ratings.fillna(0, inplace=True)
beer_index = ratings.columns
ratings.shape
# Out:
# (104, 7205)

# %%
ratings.head()
# Out:
# names                         $ellout $tout   'Tis The Saison   'Zula Stout  \
# estilo
#  Altbier                                0.0               0.0           0.0
#  American Adjunct Lager                 0.0               0.0           0.0
#  American Amber / Red Ale               0.0               0.0           0.0
#  American Amber / Red Lager             0.0               0.0           0.0
#  American Barleywine                    0.0               0.0           0.0
#
# names                         't Gaverhopke Zingende Blondine  \
# estilo
#  Altbier                                                  0.0
#  American Adjunct Lager                                   0.0
#  American Amber / Red Ale                                 0.0
#  American Amber / Red Lager                               0.0
#  American Barleywine                                      0.0
#
# names                         't Smisje Blond   't Smisje Fiori  \
# estilo
#  Altbier                                  0.0               0.0
#  American Adjunct Lager                   0.0               0.0
#  American Amber / Red Ale                 0.0               0.0
#  American Amber / Red Lager               0.0               0.0
#  American Barleywine                      0.0               0.0
#
# names                         't Smisje Grande Reserva  \
# estilo
#  Altbier                                           0.0
#  American Adjunct Lager                            0.0
#  American Amber / Red Ale                          0.0
#  American Amber / Red Lager                        0.0
#  American Barleywine                               0.0
#
# names                         't Smisje Great Reserva   't Smisje Tripel  \
# estilo
#  Altbier                                          0.0                0.0
#  American Adjunct Lager                           0.0                0.0
#  American Amber / Red Ale                         0.0                0.0
#  American Amber / Red Lager                       0.0                0.0
#  American Barleywine                              0.0                0.0
#
# names                         (512) Cascabel Cream Stout  \
# estilo
#  Altbier                                             0.0
#  American Adjunct Lager                              0.0
#  American Amber / Red Ale                            0.0
#  American Amber / Red Lager                          0.0
#  American Barleywine                                 0.0
#
# names                                              ...                         \
# estilo                                             ...
#  Altbier                                           ...
#  American Adjunct Lager                            ...
#  American Amber / Red Ale                          ...
#  American Amber / Red Lager                        ...
#  American Barleywine                               ...
#
# names                        " La Malagne (for Archaeopark, Rochefort)"  \
# estilo
#  Altbier                                                            0.0
#  American Adjunct Lager                                             0.0
#  American Amber / Red Ale                                           0.0
#  American Amber / Red Lager                                         0.0
#  American Barleywine                                                0.0
#
# names                        " Mischief, Double Dry-Hopped"  \
# estilo
#  Altbier                                                0.0
#  American Adjunct Lager                                 0.0
#  American Amber / Red Ale                               0.0
#  American Amber / Red Lager                             0.0
#  American Barleywine                                    0.0
#
# names                        " Nice Guy, Dud Root"  \
# estilo
#  Altbier                                       0.0
#  American Adjunct Lager                        0.0
#  American Amber / Red Ale                      0.0
#  American Amber / Red Lager                    0.0
#  American Barleywine                           0.0
#
# names                        " Saison De Lente, 100% Brett"  \
# estilo
#  Altbier                                                0.0
#  American Adjunct Lager                                 0.0
#  American Amber / Red Ale                               0.0
#  American Amber / Red Lager                             0.0
#  American Barleywine                                    0.0
#
# names                        " Schell's Anniversary Series #8, 1905 V.T. (Vacuum Tonic)"  \
# estilo
#  Altbier                                                                   0.0
#  American Adjunct Lager                                                    0.0
#  American Amber / Red Ale                                                  0.0
#  American Amber / Red Lager                                                0.0
#  American Barleywine                                                       0.0
#
# names                        " Schlafly ""Sofa King"" Red Ale"  \
# estilo
#  Altbier                                                   0.0
#  American Adjunct Lager                                    0.0
#  American Amber / Red Ale                                  4.0
#  American Amber / Red Lager                                0.0
#  American Barleywine                                       0.0
#
# names                        " Schlafly #20, Volume 1 - Imperial Pilsner"  \
# estilo
#  Altbier                                                              0.0
#  American Adjunct Lager                                               0.0
#  American Amber / Red Ale                                             0.0
#  American Amber / Red Lager                                           0.0
#  American Barleywine                                                  0.0
#
# names                        " Tovarish With Cacao, Toasted Almond & Coconut"  \
# estilo
#  Altbier                                                                  0.0
#  American Adjunct Lager                                                   0.0
#  American Amber / Red Ale                                                 0.0
#  American Amber / Red Lager                                               0.0
#  American Barleywine                                                      0.0
#
# names                        " Upright (""Punk Rock"" Strong) Lager"  \
# estilo
#  Altbier                                                         0.0
#  American Adjunct Lager                                          0.0
#  American Amber / Red Ale                                        0.0
#  American Amber / Red Lager                                      0.0
#  American Barleywine                                             0.0
#
# names                        " Zeppelin (for Den Ouden Advokaat, St.Pauwels)"
# estilo
#  Altbier                                                                  0.0
#  American Adjunct Lager                                                   0.0
#  American Amber / Red Ale                                                 0.0
#  American Amber / Red Lager                                               0.0
#  American Barleywine                                                      0.0
#
# [5 rows x 7205 columns]

# %% [markdown]
# ### Corrcoef returns Pearson product-moment correlation coefficients

# %%
corr_matrix= np.corrcoef(ratings.T)
corr_matrix.shape
# Out:
# (7205L, 7205L)

# %% [markdown]
# ### we create a similatity beer function to get all the similarities with other beers.

# %%
def get_beer_similarity(names):  
    '''Returns correlation vector for a beer'''
    beer_idx = list(beer_index).index(names)
    return corr_matrix[beer_idx]

# %%
a=get_beer_similarity(" Pumpkin Ale")
a.shape
# Out:
# (7205L,)

# %%
a
# Out:
# array([-0.00970874, -0.00970874, -0.00970874, ..., -0.00970874,
#        -0.00970874, -0.00970874])

# %% [markdown]
# ### make a function to input user beers which returns a matrix with recommendations

# %%
def get_beer_recommendations(stl):  
    '''given a set of beers, it returns all the beers sorted by their correlation with the style'''
   
    beer_similarities = np.zeros(corr_matrix.shape[0])
    for Id in stl:
        beer_similarities = beer_similarities + get_beer_similarity(Id)
    similarities_df = pd.DataFrame({
        'beer_name': beer_index,
        'sum_similarity': beer_similarities
        })
    similarities_df = similarities_df[~(similarities_df.beer_name.isin(stl))]
    similarities_df = similarities_df.sort_values(by=['sum_similarity'], ascending=False)
    return similarities_df.beer_name.head(5)

# %%
sample_style = ' American Adjunct Lager'
df[df.estilo==sample_style].sort_values(by=['overall'], ascending=False)
# Out:
#       user_id      profile_name     Id                              names  \
# 4431     6317          JISurfer  43981                              Primo
# 4423     6317          JISurfer   1642                            Bud Ice
# 4457     6317          JISurfer   6887                          Sambadoro
# 1843    19964        flagmantho    831                     Sagres Cerveja
# 6383      977         BMoney575   3759    Michigan Brewing Hamtramck Beer
# 3294    30047            sleazo  26313                           Victoria
# 4070    21977          jackndan   5271                          Tank Beer
# 4072    21977          jackndan   2966                         Belco Beer
# 4113    23311          jsprain1  64979                          Godfather
# 2428    10180          Redrover  33288                 Yellow Moon Rice'n
# 4881    23572             katan   6312                   Kamenitza Svetlo
# 4888    23572             katan   7515                               Alfa
# 4483    11105       SilentSabre   3741                            Cristal
# 1196     1404           BeerSox  47181                        Honey Lager
# 352     33346          zoso1967  20817                    Lawnmower Lager
# 685      5232   GratefulBeerGuy   6264                      Honey Pilsner
# 4396    29484        scruffwhor   7364                         Cisk Lager
# 5510    30486      srandycarter  26195                          Barrilito
# 4459     6317          JISurfer   5654                             Hinano
# 5091      594           AltBock  17806           Ringneck Big Woody Lager
# 5256    23603         kbnooshay   1367                         Labatt Ice
# 4478    11105       SilentSabre   6718                  Saris 12% Premium
# 4924    26632         neenerzig  27931                              Cobra
# 5273     9359          Oxymoron   5681                        Temple Br├ñu
# 5343    13033     WanderingFool  32972            333 Premium Export Beer
# 4471     6317          JISurfer  60050            Sharky's Deluxe Pilsner
# 5366     1680            BigBry  17682                     Neustadt Lager
# 5487    30486      srandycarter   2970            Taj Mahal Premium Lager
# 6108    16341        buckeyesox  40506      Foster's Export Premium Lager
# 135     19981         flexabull   2772             Stoney's Premium Lager
# ...       ...               ...    ...                                ...
# 2199     5454          HalfFull  37207                   Lighthouse Lager
# 3312    28689      riversider76  21709                      Saigon Export
# 1767    18320         dedrinker   1299                           Icehouse
# 1636    32596         wcudwight   4825                      Lucayan Lager
# 1505    12846            Vancer   6393                               Skol
# 1419    12846            Vancer   2910                         Presidente
# 1418    12846            Vancer   7447                       Brahma Chopp
# 1344    18368    deltatauhobbit   5317                         Salva Vida
# 962      7111          Kegatron  65125               Cabbage Hill Pilsner
# 3091     3020        Clydesdale  48648    Defender's Choice Premium Lager
# 3322    28689      riversider76   3378                             Brador
# 4333    29484        scruffwhor  27269              LaGrange Golden Light
# 4092    21977          jackndan   1480                        Fiji Bitter
# 214      3849         DogFood11   3940                           Imperial
# 4219     1625           BierFan   1286           Milwaukee's Best Premium
# 4210     1625           BierFan   1295                         Super Bock
# 4178    22904           joecast   1532                       Hahn Premium
# 4176    22904           joecast  13640   Cascade Four Seasons Spring Fest
# 4162    22904           joecast  13488                   St Arnou Premium
# 4097     8585       Mosstrooper   5113                  Topvar 12% Svetl├®
# 3912    13444             Zorro  11474            San Lucas Special Lager
# 3325    28689      riversider76   1318                           Schaefer
# 3863    13444             Zorro  25000         India Special Quality Beer
# 3833    26455             mynie   3039                    Zagorka Special
# 3828    26455             mynie  26755                          Northstar
# 3827    26455             mynie   2682              Michelob Golden Draft
# 3753    26455             mynie   1466                   Coors Extra Gold
# 3666     8721         MuddyFeet  34323                           Latitude
# 3327    28689      riversider76  23781                           Prestige
# 7575    16774           cdkrenz  52819       Ed Hardy Death Or Light Beer
#
#       num_rated_beers                   estilo  overall
# 4431              561   American Adjunct Lager      5.0
# 4423              561   American Adjunct Lager      5.0
# 4457              561   American Adjunct Lager      4.5
# 1843              948   American Adjunct Lager      4.5
# 6383              724   American Adjunct Lager      4.5
# 3294              593   American Adjunct Lager      4.5
# 4070              567   American Adjunct Lager      4.5
# 4072              567   American Adjunct Lager      4.5
# 4113              764   American Adjunct Lager      4.5
# 2428             1178   American Adjunct Lager      4.5
# 4881              803   American Adjunct Lager      4.5
# 4888              803   American Adjunct Lager      4.5
# 4483              691   American Adjunct Lager      4.5
# 1196             1167   American Adjunct Lager      4.5
# 352               509   American Adjunct Lager      4.5
# 685              1018   American Adjunct Lager      4.5
# 4396             1715   American Adjunct Lager      4.5
# 5510             1276   American Adjunct Lager      4.5
# 4459              561   American Adjunct Lager      4.0
# 5091              839   American Adjunct Lager      4.0
# 5256              514   American Adjunct Lager      4.0
# 4478              691   American Adjunct Lager      4.0
# 4924              559   American Adjunct Lager      4.0
# 5273              853   American Adjunct Lager      4.0
# 5343              613   American Adjunct Lager      4.0
# 4471              561   American Adjunct Lager      4.0
# 5366              787   American Adjunct Lager      4.0
# 5487             1276   American Adjunct Lager      4.0
# 6108              572   American Adjunct Lager      4.0
# 135              1255   American Adjunct Lager      4.0
# ...               ...                      ...      ...
# 2199              932   American Adjunct Lager      4.0
# 3312              606   American Adjunct Lager      4.0
# 1767              534   American Adjunct Lager      4.0
# 1636              793   American Adjunct Lager      4.0
# 1505             1641   American Adjunct Lager      4.0
# 1419             1641   American Adjunct Lager      4.0
# 1418             1641   American Adjunct Lager      4.0
# 1344              825   American Adjunct Lager      4.0
# 962              2150   American Adjunct Lager      4.0
# 3091              566   American Adjunct Lager      4.0
# 3322              606   American Adjunct Lager      4.0
# 4333             1715   American Adjunct Lager      4.0
# 4092              567   American Adjunct Lager      4.0
# 214              1200   American Adjunct Lager      4.0
# 4219              757   American Adjunct Lager      4.0
# 4210              757   American Adjunct Lager      4.0
# 4178              522   American Adjunct Lager      4.0
# 4176              522   American Adjunct Lager      4.0
# 4162              522   American Adjunct Lager      4.0
# 4097              555   American Adjunct Lager      4.0
# 3912             2197   American Adjunct Lager      4.0
# 3325              606   American Adjunct Lager      4.0
# 3863             2197   American Adjunct Lager      4.0
# 3833             1498   American Adjunct Lager      4.0
# 3828             1498   American Adjunct Lager      4.0
# 3827             1498   American Adjunct Lager      4.0
# 3753             1498   American Adjunct Lager      4.0
# 3666              938   American Adjunct Lager      4.0
# 3327              606   American Adjunct Lager      4.0
# 7575              683   American Adjunct Lager      4.0
#
# [92 rows x 7 columns]

# %%
sample_style_beers = df[df.estilo==sample_style].names.tolist()  
recommendations = get_beer_recommendations(sample_style_beers)
recommendations
# Out:
# 1190              British Bulldog
# 4483          New Speedway Bitter
# 4352     Morrissey Fox Blonde Ale
# 2759                    Goldihops
# 2761                     Goldings
# Name: beer_name, dtype: object

# %%
df1=df[df.estilo==sample_style].head(5)
df1=df1.filter(items=['estilo'])
df1.reset_index(inplace=True)
df1
# Out:
#    index                   estilo
# 0    135   American Adjunct Lager
# 1    214   American Adjunct Lager
# 2    352   American Adjunct Lager
# 3    685   American Adjunct Lager
# 4    962   American Adjunct Lager

# %%
df_final=recommendations.to_frame()
df_final.reset_index(inplace=True)
df_final
# Out:
#    index                  beer_name
# 0   1190            British Bulldog
# 1   4483        New Speedway Bitter
# 2   4352   Morrissey Fox Blonde Ale
# 3   2759                  Goldihops
# 4   2761                   Goldings

# %%
df_final_prueba=pd.concat([df1['estilo'], df_final['beer_name']], axis=1)

# %%
df_final_prueba
# Out:
#                     estilo                  beer_name
# 0   American Adjunct Lager            British Bulldog
# 1   American Adjunct Lager        New Speedway Bitter
# 2   American Adjunct Lager   Morrissey Fox Blonde Ale
# 3   American Adjunct Lager                  Goldihops
# 4   American Adjunct Lager                   Goldings

# %%
df_filtered = df[df['estilo'] == " American Adjunct Lager"]
df_filtered
# Out:
#       user_id      profile_name     Id                             names  \
# 135     19981         flexabull   2772            Stoney's Premium Lager
# 214      3849         DogFood11   3940                          Imperial
# 352     33346          zoso1967  20817                   Lawnmower Lager
# 685      5232   GratefulBeerGuy   6264                     Honey Pilsner
# 962      7111          Kegatron  65125              Cabbage Hill Pilsner
# 1196     1404           BeerSox  47181                       Honey Lager
# 1344    18368    deltatauhobbit   5317                        Salva Vida
# 1418    12846            Vancer   7447                      Brahma Chopp
# 1419    12846            Vancer   2910                        Presidente
# 1505    12846            Vancer   6393                              Skol
# 1636    32596         wcudwight   4825                     Lucayan Lager
# 1767    18320         dedrinker   1299                          Icehouse
# 1843    19964        flagmantho    831                    Sagres Cerveja
# 2199     5454          HalfFull  37207                  Lighthouse Lager
# 2292     3340               DIM   6899                            Kubuli
# 2428    10180          Redrover  33288                Yellow Moon Rice'n
# 2466    10180          Redrover  21081             Imperial Cerveja Viva
# 2639    15667      bluejacket74   7305                        Molson Dry
# 2641    15667      bluejacket74   1210                        Falls City
# 2656    15667      bluejacket74   1363                       Rhinelander
# 2801     5255         GreenCard  22715      Vestfyen Willemoes P├Ñskebryg
# 3062    30821         sulldaddy  37636                      Alois' Lager
# 3083    16429         buschbeer   3474                         Busch Ice
# 3091     3020        Clydesdale  48648   Defender's Choice Premium Lager
# 3294    30047            sleazo  26313                          Victoria
# 3312    28689      riversider76  21709                     Saigon Export
# 3322    28689      riversider76   3378                            Brador
# 3325    28689      riversider76   1318                          Schaefer
# 3327    28689      riversider76  23781                          Prestige
# 3666     8721         MuddyFeet  34323                          Latitude
# ...       ...               ...    ...                               ...
# 5256    23603         kbnooshay   1367                        Labatt Ice
# 5273     9359          Oxymoron   5681                       Temple Br├ñu
# 5343    13033     WanderingFool  32972           333 Premium Export Beer
# 5366     1680            BigBry  17682                    Neustadt Lager
# 5487    30486      srandycarter   2970           Taj Mahal Premium Lager
# 5510    30486      srandycarter  26195                         Barrilito
# 6108    16341        buckeyesox  40506     Foster's Export Premium Lager
# 6149    17411        coldmeat23  67295                  Olympia 95% Malt
# 6200     3453            Damian   2762                     OB Lager Beer
# 6383      977         BMoney575   3759   Michigan Brewing Hamtramck Beer
# 6419    20380        generallee  14687                     Estrella Damm
# 6421    20380        generallee  17431        Molson Canadian Cold Shots
# 6514     2004          Bookseeb   8750                        Cass Fresh
# 6532     1394    BeerResearcher   6956                            Pacena
# 6542     1394    BeerResearcher   9558                           Clasica
# 6543     1394    BeerResearcher  12723                          Especial
# 6573     1394    BeerResearcher  16907                             Lager
# 6587     1394    BeerResearcher  12685                         Kommodori
# 6592     1394    BeerResearcher   8906                   Cruzcampo Lager
# 6594     1394    BeerResearcher  56293          Polar Pilsener Type Beer
# 6741    19484        elricorico   2472                           Kokanee
# 6871     8005     MaltyGoodness  25524                 Thule Export Beer
# 6965     1198     BeardedBoffin   4455                          KEO Beer
# 7195     7627    LittleCreature   1530                         XXXX Gold
# 7216     7627    LittleCreature   4463             Cascade Premium Lager
# 7224     7627    LittleCreature   3626                 Tooheys Extra Dry
# 7225     7627    LittleCreature  36092                          Mash Mex
# 7347    11185             Skidz   6096                    Sylvan Springs
# 7425     8867            Naerhu   4396                    Rheingold Beer
# 7575    16774           cdkrenz  52819      Ed Hardy Death Or Light Beer
#
#       num_rated_beers                   estilo  overall
# 135              1255   American Adjunct Lager      4.0
# 214              1200   American Adjunct Lager      4.0
# 352               509   American Adjunct Lager      4.5
# 685              1018   American Adjunct Lager      4.5
# 962              2150   American Adjunct Lager      4.0
# 1196             1167   American Adjunct Lager      4.5
# 1344              825   American Adjunct Lager      4.0
# 1418             1641   American Adjunct Lager      4.0
# 1419             1641   American Adjunct Lager      4.0
# 1505             1641   American Adjunct Lager      4.0
# 1636              793   American Adjunct Lager      4.0
# 1767              534   American Adjunct Lager      4.0
# 1843              948   American Adjunct Lager      4.5
# 2199              932   American Adjunct Lager      4.0
# 2292             1024   American Adjunct Lager      4.0
# 2428             1178   American Adjunct Lager      4.5
# 2466             1178   American Adjunct Lager      4.0
# 2639             1392   American Adjunct Lager      4.0
# 2641             1392   American Adjunct Lager      4.0
# 2656             1392   American Adjunct Lager      4.0
# 2801              743   American Adjunct Lager      4.0
# 3062             1187   American Adjunct Lager      4.0
# 3083              526   American Adjunct Lager      4.0
# 3091              566   American Adjunct Lager      4.0
# 3294              593   American Adjunct Lager      4.5
# 3312              606   American Adjunct Lager      4.0
# 3322              606   American Adjunct Lager      4.0
# 3325              606   American Adjunct Lager      4.0
# 3327              606   American Adjunct Lager      4.0
# 3666              938   American Adjunct Lager      4.0
# ...               ...                      ...      ...
# 5256              514   American Adjunct Lager      4.0
# 5273              853   American Adjunct Lager      4.0
# 5343              613   American Adjunct Lager      4.0
# 5366              787   American Adjunct Lager      4.0
# 5487             1276   American Adjunct Lager      4.0
# 5510             1276   American Adjunct Lager      4.5
# 6108              572   American Adjunct Lager      4.0
# 6149              712   American Adjunct Lager      4.0
# 6200              646   American Adjunct Lager      4.0
# 6383              724   American Adjunct Lager      4.5
# 6419              649   American Adjunct Lager      4.0
# 6421              649   American Adjunct Lager      4.0
# 6514              501   American Adjunct Lager      4.0
# 6532              837   American Adjunct Lager      4.0
# 6542              837   American Adjunct Lager      4.0
# 6543              837   American Adjunct Lager      4.0
# 6573              837   American Adjunct Lager      4.0
# 6587              837   American Adjunct Lager      4.0
# 6592              837   American Adjunct Lager      4.0
# 6594              837   American Adjunct Lager      4.0
# 6741              642   American Adjunct Lager      4.0
# 6871              765   American Adjunct Lager      4.0
# 6965              532   American Adjunct Lager      4.0
# 7195              532   American Adjunct Lager      4.0
# 7216              532   American Adjunct Lager      4.0
# 7224              532   American Adjunct Lager      4.0
# 7225              532   American Adjunct Lager      4.0
# 7347              518   American Adjunct Lager      4.0
# 7425              796   American Adjunct Lager      4.0
# 7575              683   American Adjunct Lager      4.0
#
# [92 rows x 7 columns]

# %% [markdown]
# ### Make the application
# ### Creating a dropdown list to select the style

# %% [markdown]
# ### Select your favourite style in the dropdown list below, and get your top 5 recommendations!

# %%
items = sorted(df['estilo'].unique().tolist())

def view(x=''):
    if x==x: return(get_beer_recommendations(df[df.estilo==x].names.tolist()))
     
    
w = widgets.Select(options=items)
interactive(view, x=w)
# Out:
# 566                          Barrilito
# 5521                    Sagres Cerveja
# 2443                       Firefly Ale
# 3500     Ittinger Original Klosterbr├ñu
# 7112                Yellow Moon Rice'n
# Name: beer_name, dtype: object
